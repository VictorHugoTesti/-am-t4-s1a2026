# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorHugoTesti/-ML-am-t4-s1a2026/blob/main/aula2403_am4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução de Python

# %%
a=1
b=2
print("A Soma é:", a+b)
# Out:
# A Soma é: 3

# %% [markdown]
# ## Segunda Camada

# %%
c=4
d=5
print("A Multiplicação é:", c*d)
# Out:
# A Multiplicação é: 20
